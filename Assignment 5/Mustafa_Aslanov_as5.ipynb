# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# 1 - category, 2 - title, 3 - text
data = pd.read_excel("azeri_news.xlsx", encoding='utf-8')

# %%
data.head()
# Out:
#   Category                                              Title  \
# 0  Maraqlı     Naviforce Sport Saat 2016 ilə zövqlərin ahəngi
# 1  Maraqlı  Sinir ,oynaq , sinir bel ağrılarına 3 gündə son !
# 2  Maraqlı            Dəyərindən qat-qat aşağı qiymətə Mənzil
# 3    İdman  2024 və 2028-ci il olimpiadalarının keçiriləcə...
# 4    Dünya                                 Türkiyədə zəlzələ
#
#                                         News_Article
# 0  Naviforce Sport Saat 2016 Yapon Mexanizmi Yapo...
# 1  ŞOK ! ŞOK ! ŞOK ! Xanımlar və bəylər , bel və ...
# 2  Dəyərindən qat-qat Aşağı Qiymətə. Həzi Aslanov...
# 3   2028-ci il Yay Olimpiya və Paralimpiya Oyunla...
# 4   Türkiyədə daha bir zəlzələ meydana gəlib.   L...

# %%
data['corpus'] = data['Title']+data['News_Article'] 
#using both columns at the same time doesn't work the way we need. combination of 2 columns gives slightly better accuracy
y = data["Category"]
x = data["corpus"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
cv = CountVectorizer()

# %%
train_cv = cv.fit_transform(x_train)

# %%
cv.vocabulary_
# Out:
# {'ağızdakı': 19067,
#  'sümük': 157482,
#  'iltihabına': 73977,
#  'səbəb': 158909,
#  'amillərdişlər': 9556,
#  'ağız': 19064,
#  'içərisindəki': 78903,
#  'sümüklə': 157487,
#  'tam': 161862,
#  'mənası': 107912,
#  'ilə': 74000,
#  'birləşmədən': 26412,
#  'xüsusi': 183614,
#  'tellərlə': 164207,
#  'sümüyə': 157517,
#  'yapışırlar': 185773,
#  'bu': 29232,
#  'bağlantı': 22625,
#  'mürəkkəb': 105132,
#  'bir': 26096,
#  'sistem': 151744,
#  'olaraq': 115886,
#  'dişdən': 42157,
#  'gələn': 65323,
#  'qüvvələri': 136527,
#  'göndərir': 61450,
#  'hadisə': 66239,
#  'növ': 113889,
#  'asma': 13597,
#  'vəzifə': 181086,
#  'görür': 62129,
#  'bəzən': 32699,
#  'somatik': 153015,
#  'xəstəliklər': 184295,
#  'və': 180507,
#  'lokal': 93806,
#  'təsirlərlə': 172878,
#  'dişin': 42171,
#  'əlaqə': 209664,
#  'mexanizmində': 99288,
#  'qüsurlar': 136470,
#  'yaranır': 186208,
#  'yaranan': 186128,
#  'isə': 77670,
#  'diş': 42154,
#  'arasında': 11849,
#  'ankiloz': 10203,
#  'deyilən': 40256,
#  'çıxmalar': 200152,
#  'meydana': 99347,
#  'gətirə': 65861,
#  'bilər': 25794,
#  'belə': 24005,
#  'vəziyyətdə': 181205,
#  'dişlərin': 42210,
#  'çəkilməsi': 200638,
#  'zərurəti': 196274,
#  'yarananda': 186130,
#  'sıra': 158320,
#  'ağırlaşmalara': 19025,
#  'olan': 115850,
#  'kimi': 84300,
#  'çəkilişi': 200565,
#  'normal': 112956,
#  'dişlərə': 42223,
#  'görə': 62351,
#  'mümkün': 104664,
#  'qədər': 137769,
#  'çətin': 201231,
#  'olur': 116917,
#  'içərisində': 78900,
#  'hərəkətə': 72121,
#  'gətirilməsi': 65723,
#  'sadə': 144807,
#  'olmaqla': 116313,
#  'yanaşı': 185247,
#  'dişlərdə': 42201,
#  'həddindən': 71082,
#  'artıq': 12702,
#  'travma': 167262,
#  'yetirmək': 190602,
#  'həm': 71473,
#  'də': 46473,
#  'sümüyün': 157511,
#  'qaldırılmasına': 127802,
#  'ola': 115770,
#  'hallar': 66554,
#  'ümumiyyətlə': 203823,
#  'çəkilməsinin': 200644,
#  'ardından': 12112,
#  'qalan': 127588,
#  'toxumasının': 166699,
#  'qanın': 128678,
#  'qalmasına': 128040,
#  'səbəbdən': 158917,
#  'yaxşılaşmasını': 187696,
#  'çətinləşdirir': 201269,
#  'deyerler': 40191,
#  'org': 117568,
#  'rəşad': 144422,
#  'sadıqovun': 144799,
#  'millidə': 100049,
#  'son': 153031,
#  'sözləri': 157181,
#  'rəqibin': 144013,
#  'güclü': 63571,
#  'olduğunu': 116058,
#  'oyundan': 119290,
#  'qabaq': 127043,
#  'da': 36510,
#  'qeyd': 131959,
#  'etmişdik': 52652,
#  'turnir': 168165,
#  'cədvəlində': 35742,
#  'bizdən': 26855,
#  'geridə': 59563,
#  'olsa': 116514,
#  'səviyyəli': 161202,
#  'komandadır': 86044,
#  'report': 141060,
#  'xəbər': 183781,
#  'verir': 178248,
#  'ki': 83968,
#  'bunu': 29671,
#  'azərbaycan': 17593,
#  'millisinin': 100112,
#  'futbolçusu': 57727,
#  'sadıqov': 144789,
#  '2018': 1695,
#  'ci': 34136,
#  'il': 73659,
#  'dünya': 45315,
#  'çempionatının': 198024,
#  'seçmə': 150305,
#  'mərhələsində': 108626,
#  'çexiya': 198404,
#  'yığmasına': 193521,
#  'hesablı': 68538,
#  'məğlubiyyətdən': 109699,
#  'sonra': 153107,
#  'deyib': 40193,
#  'milli': 100044,
#  'komandada': 86039,
#  'matçını': 97607,
#  'keçirən': 83655,
#  '35': 2630,
#  'yaşlı': 189155,
#  'kapitan': 81329,
#  'bildirib': 25007,
#  'çoxlu': 199116,
#  'top': 165994,
#  'itkilərinə': 77936,
#  'yol': 191163,
#  'veriblər': 178023,
#  'onun': 117205,
#  'sözlərinə': 157199,
#  'millisi': 100104,
#  'əlinə': 210040,
#  'düşən': 46329,
#  'fürsətlərdən': 57817,
#  'yaxşı': 187609,
#  'yararlanıb': 186280,
#  'komanda': 86038,
#  'yoldaşlarınız': 191214,
#  'sizə': 152129,
#  'qələbə': 138012,
#  'qazanmaq': 131229,
#  'istədiklərini': 77318,
#  'söyləyirdilər': 157100,
#  'amilin': 9547,
#  'komandanı': 86106,
#  'yandırdığını': 185316,
#  'söyləmək': 157041,
#  'olar': 115881,
#  'açığı': 18389,
#  'cür': 35463,
#  'motivasiya': 102132,
#  'görmədim': 61668,
#  'şey': 206072,
#  'yox': 191711,
#  'idi': 73200,
#  'rəqib': 143996,
#  'bəzi': 32651,
#  'epizodlarda': 51369,
#  'bizi': 26862,
#  'üstələyirdi': 204254,
#  'daha': 36639,
#  'oynaya': 119176,
#  'bilərdik': 25808,
#  'buna': 29596,
#  'rəğmən': 144421,
#  'qol': 132852,
#  'imkanlarımız': 74148,
#  'oldu': 115964,
#  'hesab': 68365,
#  'olandan': 115857,
#  'nə': 114263,
#  'baş': 22989,
#  'verdi': 177884,
#  'düşündük': 46072,
#  'qazana': 131046,
#  'bilərik': 25823,
#  'ancaq': 9950,
#  'alınmadı': 9088,
#  'yığma': 193479,
#  'karyeranızdan': 81988,
#  'razısınız': 140118,
#  'yoxsa': 191864,
#  'yerinə': 190145,
#  'yetməyən': 190817,
#  'arzular': 13112,
#  'qaldı': 127663,
#  'hər': 71858,
#  'idmançı': 73242,
#  'böyük': 30860,
#  'turnirlərdə': 168183,
#  'iştirak': 79445,
#  'etməyi': 52833,
#  'arzulayır': 13151,
#  'mən': 107878,
#  'istəyirdim': 77583,
#  'əlçatmaz': 210249,
#  'azu': 17485,
#  'düzdür': 45517,
#  'mərhələdə': 108596,
#  'yaxın': 187405,
#  'idik': 73203,
#  'şimali': 206382,
#  'rlandiya': 142066,
#  'məğlubiyyətə': 109729,
#  'şansımız': 205562,
#  'qalmışdı': 128111,
#  'təəssüflənirəm': 173850,
#  'amma': 9602,
#  '16': 1212,
#  'yığmada': 193480,
#  'oynamaq': 119048,
#  'futbolçunun': 57723,
#  'arzusu': 13186,
#  'bütün': 31314,
#  'məşqçilərimə': 109873,
#  'yoldaşlarıma': 191199,
#  'təşəkkür': 173705,
#  'edirəm': 49087,
#  'affa': 6373,
#  'ya': 184698,
#  'minnətdaram': 100581,
#  'azarkeşlərə': 17285,
#  'çox': 199023,
#  'sağ': 147968,
#  'ol': 115769,
#  'deyirəm': 40319,
#  'hamı': 66787,
#  'haqqını': 66997,
#  'halal': 66450,
#  'etsin': 52946,
#  'xeyir': 182575,
#  'verə': 178637,
#  'bilərdim': 25811,
#  'xəyal': 184563,
#  'etdiyiniz': 52395,
#  'sonluq': 153082,
#  'vardı': 176964,
#  'gün': 64249,
#  'qazansaydıq': 131291,
#  'qrupda': 134696,
#  'cü': 35356,
#  'norveç': 113039,
#  'komandaları': 86054,
#  'qabaqlamaq': 127061,
#  'nəticə': 114769,
#  'olardı': 115890,
#  'millini': 100093,
#  'kənardan': 90832,
#  'izləmək': 78466,
#  'olmayacaq': 116351,
#  'əlbəttə': 209836,
#  'olacaq': 115774,
#  'lakin': 91702,
#  'işin': 79034,
#  'sonu': 153147,
#  'olduğu': 116039,
#  'bununla': 29677,
#  'barışmalıyam': 21338,
#  'çıxmasanız': 200201,
#  'oktyabrın': 115752,
#  'almaniya': 8334,
#  'matça': 97569,
#  'gedəcəksiniz': 59109,
#  'komandanın': 86109,
#  'yanında': 185629,
#  'olacağam': 115818,
#  'robert': 142117,
#  'prosineçki': 126049,
#  'mətbuat': 109306,
#  'konfransında': 86792,
#  'oyunların': 119318,
#  'birində': 26205,
#  'dəniz': 46867,
#  'yılmazı': 193351,
#  'buraxmaq': 29800,
#  'istəyib': 77545,
#  'çıxmayıb': 200227,
#  'barədə': 21395,
#  'deyə': 40374,
#  'bilərsiniz': 25848,
#  'məşqçi': 109851,
#  'futbolçu': 57679,
#  'məsələdir': 109230,
#  'biz': 26840,
#  'şahidi': 205192,
#  'olmamışıq': 116297,
#  'məyus': 109494,
#  'görünürsünüz': 62065,
#  'əsas': 211580,
#  'məyusluğum': 109502,
#  'bugünkü': 29389,
#  'görədir': 62379,
#  'heç': 68843,
#  'vaxt': 177433,
#  'məğlubiyyətlə': 109714,
#  'barışmamışam': 21343,
#  'həzm': 72554,
#  'etməmişəm': 52759,
#  'oyuna': 119255,
#  'köklənmişdim': 89432,
#  'azarkeşlər': 17266,
#  'sizi': 152101,
#  'layiqincə': 92237,
#  'yola': 191164,
#  'saldılar': 145454,
#  'birinə': 26220,
#  'dəstəklədilər': 47563,
#  'adımızı': 6207,
#  'səsləndirdilər': 160915,
#  'olsunlar': 116537,
#  'de': 38958,
#  'mistura': 101056,
#  'suriya': 156185,
#  'müxalifəti': 105692,
#  'anlamalıdır': 10250,
#  'müharibəni': 104313,
#  'uduzub': 174245,
#  'bəşər': 32743,
#  'əsəd': 212110,
#  'hökumətinə': 70313,
#  'qarşı': 129615,
#  'müharibədə': 104298,
#  'məğlub': 109692,
#  'olub': 116540,
#  'faktxeber': 54204,
#  'com': 34776,
#  'un': 174655,
#  'verdiyi': 177932,
#  'məlumata': 107541,
#  'bmt': 27365,
#  'katibinin': 82355,
#  'üzrə': 204559,
#  'nümayəndəsi': 114126,
#  'staffan': 154469,
#  'bəyan': 32407,
#  'edib': 48585,
#  'mülayim': 104595,
#  'müxalifətə': 105711,
#  'reallıqla': 140344,
#  'barışmağa': 21363,
#  'çağırıb': 197770,
#  'xatırladaq': 182316,
#  'abş': 5392,
#  'ın': 205001,
#  'suriyadakı': 156187,
#  'sonuncu': 153171,
#  'səfiri': 159188,
#  'ford': 56418,
#  'müddət': 104078,
#  'əvvəl': 212397,
#  'prezidentinin': 125198,
#  'qələbəsinin': 138054,
#  'regionun': 140623,
#  'alışmalı': 9236,
#  'hal': 66447,
#  'demişdi': 39414,
#  'olduğumuz': 116046,
#  'yeni': 189743,
#  'reallıqdır': 140343,
#  'edə': 49165,
#  'bilmərik': 25572,
#  'vurğulayıb': 180358,
#  'əlavə': 209790,
#  'keçmişdə': 83692,
#  'azad': 17011,
#  'ordusu': 117536,
#  'ünsürlərini': 203903,
#  'dəstəkləyən': 47693,
#  'xarici': 182126,
#  'hökumətlər': 70317,
#  'demokratik': 39437,
#  'qüvvələrinin': 136539,
#  'şi': 206188,
#  'hərbi': 71883,
#  'müşavirlərə': 105961,
#  'pul': 126409,
#  'silah': 150749,
#  'göndərməyə': 61512,
#  'hazır': 67563,
#  'olmadıqca': 116190,
#  'əsədi': 212113,
#  'müttəfiqlərini': 105502,
#  'etmək': 52706,
#  'imkansız': 74164,
#  'etsələr': 52952,
#  'ehtimal': 49439,
#  'üzərinə': 204822,
#  'əvəzinə': 212490,
#  'dalana': 36750,
#  'dirənmiş': 41719,
#  'uzunmüddətli': 175949,
#  'müharibə': 104295,
#  'əldə': 209856,
#  'edəcəklər': 49193,
#  'sabiq': 144594,
#  'diplomatın': 41471,
#  'tədricən': 170212,
#  'bitmək': 26758,
#  'üzrədir': 204561,
#  'prezidenti': 125183,
#  'çalıb': 196567,
#  'hakimiyyətdə': 66372,
#  'qalacaq': 127532,
#  'məhkəmədə': 106986,
#  'cavab': 33456,
#  'verəcək': 178639,
#  'vətəndaş': 180947,
#  'azadlıqlarının': 17040,
#  'müdafiəsi': 103987,
#  'ttifaqı': 167753,
#  'aclu': 5476,
#  'prezident': 125177,
#  'donald': 42782,
#  'trampın': 167062,
#  'imzaladığı': 74385,
#  'miqrasiya': 100696,
#  'fərmanı': 58376,
#  'əlaqədar': 209667,
#  'ölkə': 201902,
#  'başçısına': 23570,
#  'məhkəmə': 106985,
#  'iddiası': 73083,
#  'qaldıracaqlar': 127688,
#  'publika': 126363,
#  'az': 16973,
#  'nun': 113560,
#  'yaydığı': 187785,
#  'bəyanatda': 32413,
#  'bildirilir': 25031,
#  'sentyabrın': 148775,
#  '25': 2067,
#  'tramp': 167049,
#  'ölkənin': 201978,
#  'vətəndaşlarının': 180976,
#  'girişini': 60523,
#  'qadağan': 127341,
#  'edən': 49252,
#  'fərman': 58361,
#  'imzalayıb': 74503,
#  'fərmanla': 58366,
#  'kxdr': 89315,
#  'venesuela': 177787,
#  'çad': 196437,
#  'ran': 139495,
#  'somali': 153007,
#  'yəmən': 193759,
#  'girişinə': 60525,
#  'məhdudiyyət': 106839,
#  'qoyulub': 134134,
#  '18': 1390,
#  'dən': 46865,
#  'etibarən': 52470,
#  'qüvvəyə': 136583,
#  'minən': 100639,
#  'fərmanın': 58378,
#  'müddətsiz': 104110,
#  'türk': 169383,
#  'kəndi': 90930,
#  'etdi': 52028,
#  'dlibdə': 42260,
#  'ilk': 73837,
#  'dlibin': 42265,
#  'ordusunun': 117544,
#  'nəzarətinə': 114979,
#  'keçib': 83138,
#  'türkiyə': 169409,
#  'silahlı': 150837,
#  'birgə': 26128,
#  'keçirdiyi': 83256,
#  'əməliyyat': 210773,
#  'nəticəsində': 114859,
#  '20': 1662,
#  'kilometrlik': 84204,
#  'ərazi': 211134,
#  'kənd': 90919,
#  'nəzarətə': 114999,
#  'götürülüb': 62899,
#  'təmzilənən': 171594,
#  'ərazilərdə': 211143,
#  '30': 2400,
#  'dan': 37037,
#  'post': 124481,
#  'yaradılıb': 185952,
#  'təxribat': 173218,
#  'hücumları': 70532,
#  'plana': 123347,
#  'uyğun': 175433,
#  'davam': 37814,
#  'edir': 49008,
#  'mənbələr': 107937,
#  'növbəti': 113922,
#  'hədəfin': 71182,
#  'zzət': 195350,
#  'təpəsi': 171867,
#  'deyirlər': 40307,
#  'xezerxeber': 182667,
#  '76': 4269,
#  'dəfə': 46573,
#  'oxunub': 118691,
#  'toylarına': 166873,
#  'gedən': 59128,
#  'gəlin': 64929,
#  'bəy': 32404,
#  'hamını': 66798,
#  'təəccübləndirdi': 173731,
#  'foto': 56745,
#  'öncə': 202393,
#  'bakıda': 20211,
#  'maraqlı': 96683,
#  'yaşanıb': 188941,
#  'toyu': 166885,
#  'cütlük': 35487,
#  'səməd': 159945,
#  'vurğun': 180372,
#  'küçəsində': 90482,
#  'dayanacaqda': 38073,
#  'avtobus': 15408,
#  'gözləyərək': 63383,
#  'şadlıq': 205098,
#  'sarayına': 146431,
#  'getmək': 59837,
#  'üçün': 204909,
#  'ictimai': 72902,
#  'nəqliyyatı': 114600,
#  'seçiblər': 150074,
#  'edək': 49244,
#  'deputat': 39841,
#  'aydın': 16249,
#  'mirzəzadə': 100890,
#  'öz': 203191,
#  'hesabından': 68556,
#  'paylaşaraq': 121495,
#  'indiki': 74959,
#  'gəlinlər': 64968,
#  'təəcübləndirməyi': 173806,
#  'bacarırlar': 19747,
#  'xoşbəxt': 183175,
#  'qeydini': 131968,
#  'yazıb': 188351,
#  'küçənin': 90479,
#  'ortasında': 117810,
#  'doğdu': 43257,
#  'vi': 178837,
#  'deoqadın': 39697,
#  'uşaını': 176412,
#  'qucağına': 134985,
#  'alaraq': 7577,
#  'yoluna': 191403,
#  'əhalisinin': 209243,
#  'sayı': 147740,
#  'milyardı': 100266,
#  'ötən': 202857,
#  'çində': 198652,
#  'qəribə': 138428,
#  'verib': 178004,
#  'hamilə': 66707,
#  'qadın': 127388,
#  'alış': 9195,
#  'veriş': 178291,
#  'zamanı': 194082,
#  'elə': 50545,
#  'gəzən': 66048,
#  'zaman': 194045,
#  'körpəsini': 89785,
#  'dünyaya': 45391,
#  'gətirib': 65682,
#  'qadının': 127438,
#  'doğuş': 43517,
#  'prosesinin': 126008,
#  'başladığını': 23136,
#  'görən': 62387,
#  'küçədən': 90463,
#  'keçənlər': 83870,
#  'yerə': 190425,
#  'karton': 81898,
#  'açıb': 17989,
#  'stul': 155469,
#  'təcili': 169947,
#  'yardıma': 186491,
#  'səhiyyə': 159459,
#  'işçiləri': 79545,
#  'gəlib': 64904,
#  'çatmamış': 197371,
#  'həkimlər': 71384,
#  'körpənin': 89782,
#  'göbəyini': 61243,
#  'kəsərək': 91447,
#  'anasına': 9881,
#  'təhvil': 170556,
#  'neçə': 111991,
#  'dəqiqə': 47037,
#  'olmamış': 116288,
#  'mənbə': 107930,
#  'istipress': 77101,
#  'var': 176926,
#  'sc_cid': 148177,
#  '150627': 1108,
#  'sc_domain': 148178,
#  'ads3': 6141,
#  'adnow': 6103,
#  'sc_start_150627': 148179,
#  'new': 111859,
#  'date': 37766,
#  'gettime': 59969,
#  'dünyada': 45317,
#  'ağalarovun': 18466,
#  'qabırğaları': 127280,
#  'qırıldı': 137002,
#  'rusiyada': 143133,
#  'yaşayan': 189022,
#  'fəaliyyət': 57998,
#  'göstərən': 62737,
#  'azərbaycanlı': 17632,
#  'iş': 78928,
#  'adamı': 5665,
#  'araz': 11886,
#  'başına': 23607,
#  'biznesmen': 26931,
#  'iki': 73524,
#  'qabırğasını': 127289,
#  'sındırıb': 158275,
#  'haqda': 66923,
#  'ağalarov': 18461,
#  'zhara': 194563,
#  'tv': 168706,
#  'yə': 193715,
#  'açıqlamasında': 18211,
#  'crocus': 35143,
#  'fitness': 55958,
#  'in': 74537,
#  'açılış': 18086,
#  'mərasiminə': 108518,
#  'qatılan': 130229,
#  'ndi': 111381,
#  'güclə': 63595,
#  'dayanmışam': 38311,
#  'həftə': 71308,
#  'idmanla': 73235,
#  'məşğul': 109930,
#  'bilməyəcəm': 25628,
#  'söyləyib': 157093,
#  'söhbətə': 156807,
#  'müdaxilə': 104038,
#  'müğənni': 105844,
#  'emin': 50788,
#  'oğlan': 119463,
#  'voleybol': 179730,
#  'oynayıb': 119216,
#  'deyərək': 40427,
#  'zarafat': 194201,
#  'axşam': 16038,
#  'məhsulların': 107111,
#  'qiyməti': 132394,
#  'ucuzlaşdı': 174039,
#  '2017': 1690,
#  'ilin': 73799,
#  'avqust': 15221,
#  'ayında': 16790,
#  'bakı': 20209,
#  'şəhəri': 208112,
#  'qeyri': 132017,
#  'ərzaq': 211427,
#  'məhsullarının': 107119,
#  'qiymətləri': 132552,
#  'faiz': 54063,
#  'ucuzlaşıb': 174083,
#  'axar': 15689,
#  'istinadən': 77063,
#  'bildirir': 25058,
#  'şəhər': 208088,
#  'statistika': 154690,
#  'darəsindən': 37727,
#  'verilən': 178228,
#  'istehlak': 76813,
#  'xidmətlərin': 182730,
#  'iyul': 78349,
#  'ayına': 16787,
#  'nisbətən': 112459,
#  'bahalaşıb': 20004,
#  'dövrdə': 44795,
#  'zaqatalada': 194180,
#  'gömrük': 61342,
#  'laboratoriyası': 91577,
#  'açıldı': 18020,
#  'mərkəzi': 108674,
#  'ekspertizası': 49861,
#  'darəsinin': 37728,
#  'zaqatala': 194179,
#  'laboratoriyasının': 91583,
#  'rəsmi': 144179,
#  'mərasimi': 108500,
#  'dövlət': 44697,
#  'komitəsi': 86341,
#  'dgk': 40500,
#  'xidmətindən': 182703,
#  'mərasimdə': 108496,
#  'komitə': 86322,
#  'sədri': 159112,
#  'əliyev': 210074,
#  'rayon': 139826,
#  'rəsmiləri': 144192,
#  'bölgədə': 30491,
#  'sahibkarlar': 144961,
#  'digər': 40785,
#  'şəxslər': 208758,
#  'ediblər': 48628,
#  'rəisi': 143807,
#  'mehriban': 98363,
#  'əlizadə': 210126,
#  'laboratoriyanın': 91576,
#  'yaradılmasında': 185934,
#  'məqsəd': 108397,
#  'ölkədə': 201909,
#  'istehsal': 76848,
#  'olunan': 116654,
#  'fındıq': 57849,
#  'ixrac': 78121,
#  'potensialının': 124576,
#  'artırılması': 12820,
#  'biznes': 26894,
#  'mühitinin': 104391,
#  'yaxşılaşdırılması': 187668,
#  'sahibkarlıq': 144972,
#  'fəaliyyətində': 58022,
#  'əməyin': 210875,
#  'yüngülləşdirilməsini': 193177,
#  'təmin': 171311,
#  'etməkdir': 52710,
#  'laboratoriyasında': 91579,
#  'məhsullarında': 107113,
#  'mövcud': 103490,
#  'aflatoksinlərin': 6406,
#  'tədqiqi': 170201,
#  'aparılacaq': 11232,
#  'edilib': 48745,
#  'tərkibində': 172253,
#  'aflatoksin': 6403,
#  'ixracına': 78162,
#  'icazə': 72756,
#  'verilmir': 178146,
#  'yüksək': 192975,
#  'keyfiyyətli': 83027,
#  'ixracının': 78166,
#  'azərbaycanda': 17608,
#  'yetişdirilən': 190724,
#  'dəqiq': 46951,
#  'laborator': 91564,
#  'analizi': 9760,
#  'aparılmalıdır': 11265,
#  'təsərrüfatı': 173036,
#  'məhsulları': 107105,
#  'ən': 210883,
#  'məhsullardan': 107097,
#  'biri': 26140,
#  'məhz': 107163,
#  'fındıqdır': 57851,
#  '2016': 1688,
#  'cı': 35546,
#  'ərzində': 211452,
#  '105': 614,
#  'milyon': 100275,
#  'dollardan': 42646,
#  'məhsulu': 107126,
#  'olunub': 116852,
#  'qum': 135248,
#  'mam': 95992,
#  'məhəmməd': 107237,
#  'baqirə': 20942,
#  'əza': 212888,
#  'saxlayıri': 147470,
#  'ranın': 139541,
#  'şəhərində': 208125,
#  'zilhiccə': 194668,
#  'ayının': 16797,
#  'si': 150530,
#  'həzrət': 72571,
#  'məhəmmdə': 107235,
#  'baqirin': 20936,
#  'müsibətli': 105291,
#  'şəhadətinin': 208006,
#  'ildönümü': 73719,
#  'münasibətilə': 104760,
#  'mərasimləri': 108525,
#  'keçirilir': 83358,
#  'amfm': 9531,
#  'məsumənin': 109213,
#  'mütəhhər': 105533,
#  'hərəminin': 72138,
#  'qızılı': 137366,
#  'günbəzinə': 64364,
#  'zərihinə': 196234,
#  'qara': 128888,
#  'bayraq': 22260,
#  'yerləşdirilib': 190265,
#  'bundan': 29606,
#  'başqa': 23483,
#  'hərəmin': 72133,
#  'sütunlu': 158058,
#  'dəhlizləri': 46618,
#  'həyətlərində': 72539,
#  'bayraqlar': 22269,
#  'baqirdən': 20934,
#  'hədislər': 71107,
#  'yazılan': 188365,
#  'plakatlar': 123330,
#  'ranlı': 139524,
#  'rejissorun': 140743,
#  'filmi': 55625,
#  'film': 55619,
#  'mükafatına': 104548,
#  'layiq': 92230,
#  'görülüb': 61899,
#  'rejissor': 140709,
#  'yaser': 186976,
#  'talebin': 161691,
#  'çəkdiyi': 200493,
#  'övladlar': 202879,
#  'mükafata': 104472,
#  'lərə': 94809,
#  'veri': 178003,
#  'ekran': 49743,
#  'əsəri': 212151,
#  'təşkil': 173493,
#  'royal': 142702,
#  'star': 154617,
#  'festivalında': 55134,
#  'mükafatını': 104551,
#  'qazanıb': 131300,
#  'filmdə': 55621,
#  'rolları': 142360,
#  'hasan': 67221,
#  'rüstemani': 143411,
#  'viktoria': 179180,
#  'levşenikova': 92765,
#  'hüseyn': 70798,
#  'mirzaguli': 100842,
#  'mehrtaş': 98386,
#  'saidi': 145126,
#  'ile': 73749,
#  'pagah': 119744,
#  'kakasoltani': 80693,
#  'ifa': 73328,
#  'övladını': 202933,
#  'xaricə': 182140,
#  'təhsil': 170513,
#  'almaq': 8371,
#  'göndərən': 61532,
#  'ondan': 117063,
#  'ala': 7482,
#  'bilmədikləri': 25477,
#  'axtarışlara': 15900,
#  'başlayan': 23372,
#  'ailənin': 6753,
#  'yaşadıqlarından': 188748,
#  'bəhs': 31719,
#  'keçirilən': 83449,
#  'longleaf': 93885,
#  'ölən': 202299,
#  'əsir': 211814,
#  'rus': 143108,
#  'əsgərlərin': 211771,
#  'sayını': 147813,
#  'açıqladı': 18121,
#  'suriyanın': 156197,
#  'deyr': 40354,
#  'ez': 53632,
#  'zor': 195127,
#  'əyalətində': 212629,
#  'rusiya': 143131,
#  'əsgəri': 211743,
#  'həlak': 71407,
#  'ikisi': 73597,
#  'mediaya': 98209,
#  'terror': 164613,
#  'qruplaşmasının': 134754,
#  'amak': 9338,
#  'informasiya': 75090,
#  'agentliyi': 6542,
#  'rusiyalı': 143141,
#  'şulya': 207309,
#  'qəsəbəsi': 138568,
#  'döyüşlərin': 45034,
#  'gedişatında': 59071,
#  'bəyanatı': 32437,
#  'rusiyanın': 143157,
#  'müdafiə': 103980,
#  'nazirliyi': 111168,
#  'şərh': 208468,
#  'verməyib': 178480,
#  'ömər': 202370,
#  'cinsi': 34453,
#  'qabiliyyətiniz': 127174,
#  'təyin': 173268,
#  'olunacaq': 116628,
#  'standford': 154572,
#  'universitetin': 174772,
#  'professorları': 125583,
#  'insanın': 75453,
#  'meyillərini': 99448,
#  'fotodan': 56798,
#  'alqorifm': 8606,
#  'düzəldib': 45593,
#  'şəxsiyyət': 208722,
#  'sosial': 153430,
#  'psixologiya': 126284,
#  'jurnalı': 80296,
#  'nda': 111364,
#  'journal': 80155,
#  'of': 115471,
#  'personality': 122154,
#  'and': 9970,
#  'social': 152822,
#  'psychology': 126346,
#  'mövzuya': 103688,
#  'dair': 36687,
#  'yayımlanan': 187965,
#  'məqalədə': 108312,
#  'tək': 170564,
#  'meyli': 99477,
#  'təyinetmə': 173300,
#  'həssaslığının': 72213,
#  'kişilərdə': 85065,
#  '81': 4421,
#  'qadınlarda': 127400,
#  '74': 4213,
#  'bildirilib': 25029,
#  'yer': 190015,
#  'alan': 7541,
#  'müqayisəli': 104981,
#  'məlumatlar': 107593,
#  'insanların': 75420,
#  'mövzuda': 103649,
#  'pis': 123025,
#  'nəticələr': 114820,
#  'verdiyini': 177941,
#  'göstərib': 62457,
#  'mövzu': 103648,
#  'bağlı': 22746,
#  'araşdırmada': 11940,
#  '75': 4232,
#  '000': 1,
#  'insana': 75381,
#  'aid': 6663,
#  'istifadə': 76944,
#  'alqorifmdə': 8607,
#  'olunarkən': 116671,
#  'meylin': 99480,
#  'faizini': 54081,
#  'tapmaq': 162775,
#  'imkanının': 74182,
#  '91': 4652,
#  '83': 4458,
#  'qalxdığı': 128187,
#  'ortaya': 117815,
#  'çıxıb': 200285,
#  'homoseksual': 69681,
#  'fərdlərin': 58336,
#  'qabiliyyətinin': 127173,
#  'edilməsinə': 48889,
#  'verilib': 178079,
#  'kişilərin': 85070,
#  'fərqli': 58407,
#  'üz': 204368,
#  'quruluşu': 135906,
#  'ifadəsi': 73352,
#  'olmasına': 116339,
#  'meylinin': 99483,
#  'doğuluşundan': 43466,
#  'formalaşdığı': 56541,
#  'zümrüd': 195488,
#  'yaxt': 187375,
#  'klub': 85390,
#  'nizamnamə': 112622,
#  'kapitalı': 81320,
#  ...}

# %%
mnb = MultinomialNB()

# %%
mnb.fit(train_cv,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
test_cv = cv.transform(x_test)

# %%
predictions_cv=mnb.predict(test_cv)

# %%
print(classification_report(y_test, predictions_cv))
# Out:
#               precision    recall  f1-score   support
#
#        Dünya       0.74      0.80      0.77      2676
#      Maraqlı       0.82      0.68      0.74      3182
#   Mədəniyyət       0.83      0.66      0.73       301
#      Siyasət       0.77      0.87      0.82      1300
#        İdman       0.90      0.96      0.93      1256
# İqtisadiyyat       0.81      0.90      0.86      1285
#
#     accuracy                           0.80     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.80      0.80      0.80     10000

# %%
print(confusion_matrix(y_test, predictions_cv))
# Out:
# [[2135  331    8  107   34   61]
#  [ 618 2164   23  131   94  152]
#  [   7   62  198   30    0    4]
#  [  76   34    5 1137    2   46]
#  [  13   27    0   10 1202    4]
#  [  28   20    4   67    5 1161]]

# %%
# checking this library in case if accuracy will be higher
tfidf = TfidfVectorizer()
train_tf = tfidf.fit_transform(x_train)

# %%
tfidf.vocabulary_
# Out:
# {'ağızdakı': 19067,
#  'sümük': 157482,
#  'iltihabına': 73977,
#  'səbəb': 158909,
#  'amillərdişlər': 9556,
#  'ağız': 19064,
#  'içərisindəki': 78903,
#  'sümüklə': 157487,
#  'tam': 161862,
#  'mənası': 107912,
#  'ilə': 74000,
#  'birləşmədən': 26412,
#  'xüsusi': 183614,
#  'tellərlə': 164207,
#  'sümüyə': 157517,
#  'yapışırlar': 185773,
#  'bu': 29232,
#  'bağlantı': 22625,
#  'mürəkkəb': 105132,
#  'bir': 26096,
#  'sistem': 151744,
#  'olaraq': 115886,
#  'dişdən': 42157,
#  'gələn': 65323,
#  'qüvvələri': 136527,
#  'göndərir': 61450,
#  'hadisə': 66239,
#  'növ': 113889,
#  'asma': 13597,
#  'vəzifə': 181086,
#  'görür': 62129,
#  'bəzən': 32699,
#  'somatik': 153015,
#  'xəstəliklər': 184295,
#  'və': 180507,
#  'lokal': 93806,
#  'təsirlərlə': 172878,
#  'dişin': 42171,
#  'əlaqə': 209664,
#  'mexanizmində': 99288,
#  'qüsurlar': 136470,
#  'yaranır': 186208,
#  'yaranan': 186128,
#  'isə': 77670,
#  'diş': 42154,
#  'arasında': 11849,
#  'ankiloz': 10203,
#  'deyilən': 40256,
#  'çıxmalar': 200152,
#  'meydana': 99347,
#  'gətirə': 65861,
#  'bilər': 25794,
#  'belə': 24005,
#  'vəziyyətdə': 181205,
#  'dişlərin': 42210,
#  'çəkilməsi': 200638,
#  'zərurəti': 196274,
#  'yarananda': 186130,
#  'sıra': 158320,
#  'ağırlaşmalara': 19025,
#  'olan': 115850,
#  'kimi': 84300,
#  'çəkilişi': 200565,
#  'normal': 112956,
#  'dişlərə': 42223,
#  'görə': 62351,
#  'mümkün': 104664,
#  'qədər': 137769,
#  'çətin': 201231,
#  'olur': 116917,
#  'içərisində': 78900,
#  'hərəkətə': 72121,
#  'gətirilməsi': 65723,
#  'sadə': 144807,
#  'olmaqla': 116313,
#  'yanaşı': 185247,
#  'dişlərdə': 42201,
#  'həddindən': 71082,
#  'artıq': 12702,
#  'travma': 167262,
#  'yetirmək': 190602,
#  'həm': 71473,
#  'də': 46473,
#  'sümüyün': 157511,
#  'qaldırılmasına': 127802,
#  'ola': 115770,
#  'hallar': 66554,
#  'ümumiyyətlə': 203823,
#  'çəkilməsinin': 200644,
#  'ardından': 12112,
#  'qalan': 127588,
#  'toxumasının': 166699,
#  'qanın': 128678,
#  'qalmasına': 128040,
#  'səbəbdən': 158917,
#  'yaxşılaşmasını': 187696,
#  'çətinləşdirir': 201269,
#  'deyerler': 40191,
#  'org': 117568,
#  'rəşad': 144422,
#  'sadıqovun': 144799,
#  'millidə': 100049,
#  'son': 153031,
#  'sözləri': 157181,
#  'rəqibin': 144013,
#  'güclü': 63571,
#  'olduğunu': 116058,
#  'oyundan': 119290,
#  'qabaq': 127043,
#  'da': 36510,
#  'qeyd': 131959,
#  'etmişdik': 52652,
#  'turnir': 168165,
#  'cədvəlində': 35742,
#  'bizdən': 26855,
#  'geridə': 59563,
#  'olsa': 116514,
#  'səviyyəli': 161202,
#  'komandadır': 86044,
#  'report': 141060,
#  'xəbər': 183781,
#  'verir': 178248,
#  'ki': 83968,
#  'bunu': 29671,
#  'azərbaycan': 17593,
#  'millisinin': 100112,
#  'futbolçusu': 57727,
#  'sadıqov': 144789,
#  '2018': 1695,
#  'ci': 34136,
#  'il': 73659,
#  'dünya': 45315,
#  'çempionatının': 198024,
#  'seçmə': 150305,
#  'mərhələsində': 108626,
#  'çexiya': 198404,
#  'yığmasına': 193521,
#  'hesablı': 68538,
#  'məğlubiyyətdən': 109699,
#  'sonra': 153107,
#  'deyib': 40193,
#  'milli': 100044,
#  'komandada': 86039,
#  'matçını': 97607,
#  'keçirən': 83655,
#  '35': 2630,
#  'yaşlı': 189155,
#  'kapitan': 81329,
#  'bildirib': 25007,
#  'çoxlu': 199116,
#  'top': 165994,
#  'itkilərinə': 77936,
#  'yol': 191163,
#  'veriblər': 178023,
#  'onun': 117205,
#  'sözlərinə': 157199,
#  'millisi': 100104,
#  'əlinə': 210040,
#  'düşən': 46329,
#  'fürsətlərdən': 57817,
#  'yaxşı': 187609,
#  'yararlanıb': 186280,
#  'komanda': 86038,
#  'yoldaşlarınız': 191214,
#  'sizə': 152129,
#  'qələbə': 138012,
#  'qazanmaq': 131229,
#  'istədiklərini': 77318,
#  'söyləyirdilər': 157100,
#  'amilin': 9547,
#  'komandanı': 86106,
#  'yandırdığını': 185316,
#  'söyləmək': 157041,
#  'olar': 115881,
#  'açığı': 18389,
#  'cür': 35463,
#  'motivasiya': 102132,
#  'görmədim': 61668,
#  'şey': 206072,
#  'yox': 191711,
#  'idi': 73200,
#  'rəqib': 143996,
#  'bəzi': 32651,
#  'epizodlarda': 51369,
#  'bizi': 26862,
#  'üstələyirdi': 204254,
#  'daha': 36639,
#  'oynaya': 119176,
#  'bilərdik': 25808,
#  'buna': 29596,
#  'rəğmən': 144421,
#  'qol': 132852,
#  'imkanlarımız': 74148,
#  'oldu': 115964,
#  'hesab': 68365,
#  'olandan': 115857,
#  'nə': 114263,
#  'baş': 22989,
#  'verdi': 177884,
#  'düşündük': 46072,
#  'qazana': 131046,
#  'bilərik': 25823,
#  'ancaq': 9950,
#  'alınmadı': 9088,
#  'yığma': 193479,
#  'karyeranızdan': 81988,
#  'razısınız': 140118,
#  'yoxsa': 191864,
#  'yerinə': 190145,
#  'yetməyən': 190817,
#  'arzular': 13112,
#  'qaldı': 127663,
#  'hər': 71858,
#  'idmançı': 73242,
#  'böyük': 30860,
#  'turnirlərdə': 168183,
#  'iştirak': 79445,
#  'etməyi': 52833,
#  'arzulayır': 13151,
#  'mən': 107878,
#  'istəyirdim': 77583,
#  'əlçatmaz': 210249,
#  'azu': 17485,
#  'düzdür': 45517,
#  'mərhələdə': 108596,
#  'yaxın': 187405,
#  'idik': 73203,
#  'şimali': 206382,
#  'rlandiya': 142066,
#  'məğlubiyyətə': 109729,
#  'şansımız': 205562,
#  'qalmışdı': 128111,
#  'təəssüflənirəm': 173850,
#  'amma': 9602,
#  '16': 1212,
#  'yığmada': 193480,
#  'oynamaq': 119048,
#  'futbolçunun': 57723,
#  'arzusu': 13186,
#  'bütün': 31314,
#  'məşqçilərimə': 109873,
#  'yoldaşlarıma': 191199,
#  'təşəkkür': 173705,
#  'edirəm': 49087,
#  'affa': 6373,
#  'ya': 184698,
#  'minnətdaram': 100581,
#  'azarkeşlərə': 17285,
#  'çox': 199023,
#  'sağ': 147968,
#  'ol': 115769,
#  'deyirəm': 40319,
#  'hamı': 66787,
#  'haqqını': 66997,
#  'halal': 66450,
#  'etsin': 52946,
#  'xeyir': 182575,
#  'verə': 178637,
#  'bilərdim': 25811,
#  'xəyal': 184563,
#  'etdiyiniz': 52395,
#  'sonluq': 153082,
#  'vardı': 176964,
#  'gün': 64249,
#  'qazansaydıq': 131291,
#  'qrupda': 134696,
#  'cü': 35356,
#  'norveç': 113039,
#  'komandaları': 86054,
#  'qabaqlamaq': 127061,
#  'nəticə': 114769,
#  'olardı': 115890,
#  'millini': 100093,
#  'kənardan': 90832,
#  'izləmək': 78466,
#  'olmayacaq': 116351,
#  'əlbəttə': 209836,
#  'olacaq': 115774,
#  'lakin': 91702,
#  'işin': 79034,
#  'sonu': 153147,
#  'olduğu': 116039,
#  'bununla': 29677,
#  'barışmalıyam': 21338,
#  'çıxmasanız': 200201,
#  'oktyabrın': 115752,
#  'almaniya': 8334,
#  'matça': 97569,
#  'gedəcəksiniz': 59109,
#  'komandanın': 86109,
#  'yanında': 185629,
#  'olacağam': 115818,
#  'robert': 142117,
#  'prosineçki': 126049,
#  'mətbuat': 109306,
#  'konfransında': 86792,
#  'oyunların': 119318,
#  'birində': 26205,
#  'dəniz': 46867,
#  'yılmazı': 193351,
#  'buraxmaq': 29800,
#  'istəyib': 77545,
#  'çıxmayıb': 200227,
#  'barədə': 21395,
#  'deyə': 40374,
#  'bilərsiniz': 25848,
#  'məşqçi': 109851,
#  'futbolçu': 57679,
#  'məsələdir': 109230,
#  'biz': 26840,
#  'şahidi': 205192,
#  'olmamışıq': 116297,
#  'məyus': 109494,
#  'görünürsünüz': 62065,
#  'əsas': 211580,
#  'məyusluğum': 109502,
#  'bugünkü': 29389,
#  'görədir': 62379,
#  'heç': 68843,
#  'vaxt': 177433,
#  'məğlubiyyətlə': 109714,
#  'barışmamışam': 21343,
#  'həzm': 72554,
#  'etməmişəm': 52759,
#  'oyuna': 119255,
#  'köklənmişdim': 89432,
#  'azarkeşlər': 17266,
#  'sizi': 152101,
#  'layiqincə': 92237,
#  'yola': 191164,
#  'saldılar': 145454,
#  'birinə': 26220,
#  'dəstəklədilər': 47563,
#  'adımızı': 6207,
#  'səsləndirdilər': 160915,
#  'olsunlar': 116537,
#  'de': 38958,
#  'mistura': 101056,
#  'suriya': 156185,
#  'müxalifəti': 105692,
#  'anlamalıdır': 10250,
#  'müharibəni': 104313,
#  'uduzub': 174245,
#  'bəşər': 32743,
#  'əsəd': 212110,
#  'hökumətinə': 70313,
#  'qarşı': 129615,
#  'müharibədə': 104298,
#  'məğlub': 109692,
#  'olub': 116540,
#  'faktxeber': 54204,
#  'com': 34776,
#  'un': 174655,
#  'verdiyi': 177932,
#  'məlumata': 107541,
#  'bmt': 27365,
#  'katibinin': 82355,
#  'üzrə': 204559,
#  'nümayəndəsi': 114126,
#  'staffan': 154469,
#  'bəyan': 32407,
#  'edib': 48585,
#  'mülayim': 104595,
#  'müxalifətə': 105711,
#  'reallıqla': 140344,
#  'barışmağa': 21363,
#  'çağırıb': 197770,
#  'xatırladaq': 182316,
#  'abş': 5392,
#  'ın': 205001,
#  'suriyadakı': 156187,
#  'sonuncu': 153171,
#  'səfiri': 159188,
#  'ford': 56418,
#  'müddət': 104078,
#  'əvvəl': 212397,
#  'prezidentinin': 125198,
#  'qələbəsinin': 138054,
#  'regionun': 140623,
#  'alışmalı': 9236,
#  'hal': 66447,
#  'demişdi': 39414,
#  'olduğumuz': 116046,
#  'yeni': 189743,
#  'reallıqdır': 140343,
#  'edə': 49165,
#  'bilmərik': 25572,
#  'vurğulayıb': 180358,
#  'əlavə': 209790,
#  'keçmişdə': 83692,
#  'azad': 17011,
#  'ordusu': 117536,
#  'ünsürlərini': 203903,
#  'dəstəkləyən': 47693,
#  'xarici': 182126,
#  'hökumətlər': 70317,
#  'demokratik': 39437,
#  'qüvvələrinin': 136539,
#  'şi': 206188,
#  'hərbi': 71883,
#  'müşavirlərə': 105961,
#  'pul': 126409,
#  'silah': 150749,
#  'göndərməyə': 61512,
#  'hazır': 67563,
#  'olmadıqca': 116190,
#  'əsədi': 212113,
#  'müttəfiqlərini': 105502,
#  'etmək': 52706,
#  'imkansız': 74164,
#  'etsələr': 52952,
#  'ehtimal': 49439,
#  'üzərinə': 204822,
#  'əvəzinə': 212490,
#  'dalana': 36750,
#  'dirənmiş': 41719,
#  'uzunmüddətli': 175949,
#  'müharibə': 104295,
#  'əldə': 209856,
#  'edəcəklər': 49193,
#  'sabiq': 144594,
#  'diplomatın': 41471,
#  'tədricən': 170212,
#  'bitmək': 26758,
#  'üzrədir': 204561,
#  'prezidenti': 125183,
#  'çalıb': 196567,
#  'hakimiyyətdə': 66372,
#  'qalacaq': 127532,
#  'məhkəmədə': 106986,
#  'cavab': 33456,
#  'verəcək': 178639,
#  'vətəndaş': 180947,
#  'azadlıqlarının': 17040,
#  'müdafiəsi': 103987,
#  'ttifaqı': 167753,
#  'aclu': 5476,
#  'prezident': 125177,
#  'donald': 42782,
#  'trampın': 167062,
#  'imzaladığı': 74385,
#  'miqrasiya': 100696,
#  'fərmanı': 58376,
#  'əlaqədar': 209667,
#  'ölkə': 201902,
#  'başçısına': 23570,
#  'məhkəmə': 106985,
#  'iddiası': 73083,
#  'qaldıracaqlar': 127688,
#  'publika': 126363,
#  'az': 16973,
#  'nun': 113560,
#  'yaydığı': 187785,
#  'bəyanatda': 32413,
#  'bildirilir': 25031,
#  'sentyabrın': 148775,
#  '25': 2067,
#  'tramp': 167049,
#  'ölkənin': 201978,
#  'vətəndaşlarının': 180976,
#  'girişini': 60523,
#  'qadağan': 127341,
#  'edən': 49252,
#  'fərman': 58361,
#  'imzalayıb': 74503,
#  'fərmanla': 58366,
#  'kxdr': 89315,
#  'venesuela': 177787,
#  'çad': 196437,
#  'ran': 139495,
#  'somali': 153007,
#  'yəmən': 193759,
#  'girişinə': 60525,
#  'məhdudiyyət': 106839,
#  'qoyulub': 134134,
#  '18': 1390,
#  'dən': 46865,
#  'etibarən': 52470,
#  'qüvvəyə': 136583,
#  'minən': 100639,
#  'fərmanın': 58378,
#  'müddətsiz': 104110,
#  'türk': 169383,
#  'kəndi': 90930,
#  'etdi': 52028,
#  'dlibdə': 42260,
#  'ilk': 73837,
#  'dlibin': 42265,
#  'ordusunun': 117544,
#  'nəzarətinə': 114979,
#  'keçib': 83138,
#  'türkiyə': 169409,
#  'silahlı': 150837,
#  'birgə': 26128,
#  'keçirdiyi': 83256,
#  'əməliyyat': 210773,
#  'nəticəsində': 114859,
#  '20': 1662,
#  'kilometrlik': 84204,
#  'ərazi': 211134,
#  'kənd': 90919,
#  'nəzarətə': 114999,
#  'götürülüb': 62899,
#  'təmzilənən': 171594,
#  'ərazilərdə': 211143,
#  '30': 2400,
#  'dan': 37037,
#  'post': 124481,
#  'yaradılıb': 185952,
#  'təxribat': 173218,
#  'hücumları': 70532,
#  'plana': 123347,
#  'uyğun': 175433,
#  'davam': 37814,
#  'edir': 49008,
#  'mənbələr': 107937,
#  'növbəti': 113922,
#  'hədəfin': 71182,
#  'zzət': 195350,
#  'təpəsi': 171867,
#  'deyirlər': 40307,
#  'xezerxeber': 182667,
#  '76': 4269,
#  'dəfə': 46573,
#  'oxunub': 118691,
#  'toylarına': 166873,
#  'gedən': 59128,
#  'gəlin': 64929,
#  'bəy': 32404,
#  'hamını': 66798,
#  'təəccübləndirdi': 173731,
#  'foto': 56745,
#  'öncə': 202393,
#  'bakıda': 20211,
#  'maraqlı': 96683,
#  'yaşanıb': 188941,
#  'toyu': 166885,
#  'cütlük': 35487,
#  'səməd': 159945,
#  'vurğun': 180372,
#  'küçəsində': 90482,
#  'dayanacaqda': 38073,
#  'avtobus': 15408,
#  'gözləyərək': 63383,
#  'şadlıq': 205098,
#  'sarayına': 146431,
#  'getmək': 59837,
#  'üçün': 204909,
#  'ictimai': 72902,
#  'nəqliyyatı': 114600,
#  'seçiblər': 150074,
#  'edək': 49244,
#  'deputat': 39841,
#  'aydın': 16249,
#  'mirzəzadə': 100890,
#  'öz': 203191,
#  'hesabından': 68556,
#  'paylaşaraq': 121495,
#  'indiki': 74959,
#  'gəlinlər': 64968,
#  'təəcübləndirməyi': 173806,
#  'bacarırlar': 19747,
#  'xoşbəxt': 183175,
#  'qeydini': 131968,
#  'yazıb': 188351,
#  'küçənin': 90479,
#  'ortasında': 117810,
#  'doğdu': 43257,
#  'vi': 178837,
#  'deoqadın': 39697,
#  'uşaını': 176412,
#  'qucağına': 134985,
#  'alaraq': 7577,
#  'yoluna': 191403,
#  'əhalisinin': 209243,
#  'sayı': 147740,
#  'milyardı': 100266,
#  'ötən': 202857,
#  'çində': 198652,
#  'qəribə': 138428,
#  'verib': 178004,
#  'hamilə': 66707,
#  'qadın': 127388,
#  'alış': 9195,
#  'veriş': 178291,
#  'zamanı': 194082,
#  'elə': 50545,
#  'gəzən': 66048,
#  'zaman': 194045,
#  'körpəsini': 89785,
#  'dünyaya': 45391,
#  'gətirib': 65682,
#  'qadının': 127438,
#  'doğuş': 43517,
#  'prosesinin': 126008,
#  'başladığını': 23136,
#  'görən': 62387,
#  'küçədən': 90463,
#  'keçənlər': 83870,
#  'yerə': 190425,
#  'karton': 81898,
#  'açıb': 17989,
#  'stul': 155469,
#  'təcili': 169947,
#  'yardıma': 186491,
#  'səhiyyə': 159459,
#  'işçiləri': 79545,
#  'gəlib': 64904,
#  'çatmamış': 197371,
#  'həkimlər': 71384,
#  'körpənin': 89782,
#  'göbəyini': 61243,
#  'kəsərək': 91447,
#  'anasına': 9881,
#  'təhvil': 170556,
#  'neçə': 111991,
#  'dəqiqə': 47037,
#  'olmamış': 116288,
#  'mənbə': 107930,
#  'istipress': 77101,
#  'var': 176926,
#  'sc_cid': 148177,
#  '150627': 1108,
#  'sc_domain': 148178,
#  'ads3': 6141,
#  'adnow': 6103,
#  'sc_start_150627': 148179,
#  'new': 111859,
#  'date': 37766,
#  'gettime': 59969,
#  'dünyada': 45317,
#  'ağalarovun': 18466,
#  'qabırğaları': 127280,
#  'qırıldı': 137002,
#  'rusiyada': 143133,
#  'yaşayan': 189022,
#  'fəaliyyət': 57998,
#  'göstərən': 62737,
#  'azərbaycanlı': 17632,
#  'iş': 78928,
#  'adamı': 5665,
#  'araz': 11886,
#  'başına': 23607,
#  'biznesmen': 26931,
#  'iki': 73524,
#  'qabırğasını': 127289,
#  'sındırıb': 158275,
#  'haqda': 66923,
#  'ağalarov': 18461,
#  'zhara': 194563,
#  'tv': 168706,
#  'yə': 193715,
#  'açıqlamasında': 18211,
#  'crocus': 35143,
#  'fitness': 55958,
#  'in': 74537,
#  'açılış': 18086,
#  'mərasiminə': 108518,
#  'qatılan': 130229,
#  'ndi': 111381,
#  'güclə': 63595,
#  'dayanmışam': 38311,
#  'həftə': 71308,
#  'idmanla': 73235,
#  'məşğul': 109930,
#  'bilməyəcəm': 25628,
#  'söyləyib': 157093,
#  'söhbətə': 156807,
#  'müdaxilə': 104038,
#  'müğənni': 105844,
#  'emin': 50788,
#  'oğlan': 119463,
#  'voleybol': 179730,
#  'oynayıb': 119216,
#  'deyərək': 40427,
#  'zarafat': 194201,
#  'axşam': 16038,
#  'məhsulların': 107111,
#  'qiyməti': 132394,
#  'ucuzlaşdı': 174039,
#  '2017': 1690,
#  'ilin': 73799,
#  'avqust': 15221,
#  'ayında': 16790,
#  'bakı': 20209,
#  'şəhəri': 208112,
#  'qeyri': 132017,
#  'ərzaq': 211427,
#  'məhsullarının': 107119,
#  'qiymətləri': 132552,
#  'faiz': 54063,
#  'ucuzlaşıb': 174083,
#  'axar': 15689,
#  'istinadən': 77063,
#  'bildirir': 25058,
#  'şəhər': 208088,
#  'statistika': 154690,
#  'darəsindən': 37727,
#  'verilən': 178228,
#  'istehlak': 76813,
#  'xidmətlərin': 182730,
#  'iyul': 78349,
#  'ayına': 16787,
#  'nisbətən': 112459,
#  'bahalaşıb': 20004,
#  'dövrdə': 44795,
#  'zaqatalada': 194180,
#  'gömrük': 61342,
#  'laboratoriyası': 91577,
#  'açıldı': 18020,
#  'mərkəzi': 108674,
#  'ekspertizası': 49861,
#  'darəsinin': 37728,
#  'zaqatala': 194179,
#  'laboratoriyasının': 91583,
#  'rəsmi': 144179,
#  'mərasimi': 108500,
#  'dövlət': 44697,
#  'komitəsi': 86341,
#  'dgk': 40500,
#  'xidmətindən': 182703,
#  'mərasimdə': 108496,
#  'komitə': 86322,
#  'sədri': 159112,
#  'əliyev': 210074,
#  'rayon': 139826,
#  'rəsmiləri': 144192,
#  'bölgədə': 30491,
#  'sahibkarlar': 144961,
#  'digər': 40785,
#  'şəxslər': 208758,
#  'ediblər': 48628,
#  'rəisi': 143807,
#  'mehriban': 98363,
#  'əlizadə': 210126,
#  'laboratoriyanın': 91576,
#  'yaradılmasında': 185934,
#  'məqsəd': 108397,
#  'ölkədə': 201909,
#  'istehsal': 76848,
#  'olunan': 116654,
#  'fındıq': 57849,
#  'ixrac': 78121,
#  'potensialının': 124576,
#  'artırılması': 12820,
#  'biznes': 26894,
#  'mühitinin': 104391,
#  'yaxşılaşdırılması': 187668,
#  'sahibkarlıq': 144972,
#  'fəaliyyətində': 58022,
#  'əməyin': 210875,
#  'yüngülləşdirilməsini': 193177,
#  'təmin': 171311,
#  'etməkdir': 52710,
#  'laboratoriyasında': 91579,
#  'məhsullarında': 107113,
#  'mövcud': 103490,
#  'aflatoksinlərin': 6406,
#  'tədqiqi': 170201,
#  'aparılacaq': 11232,
#  'edilib': 48745,
#  'tərkibində': 172253,
#  'aflatoksin': 6403,
#  'ixracına': 78162,
#  'icazə': 72756,
#  'verilmir': 178146,
#  'yüksək': 192975,
#  'keyfiyyətli': 83027,
#  'ixracının': 78166,
#  'azərbaycanda': 17608,
#  'yetişdirilən': 190724,
#  'dəqiq': 46951,
#  'laborator': 91564,
#  'analizi': 9760,
#  'aparılmalıdır': 11265,
#  'təsərrüfatı': 173036,
#  'məhsulları': 107105,
#  'ən': 210883,
#  'məhsullardan': 107097,
#  'biri': 26140,
#  'məhz': 107163,
#  'fındıqdır': 57851,
#  '2016': 1688,
#  'cı': 35546,
#  'ərzində': 211452,
#  '105': 614,
#  'milyon': 100275,
#  'dollardan': 42646,
#  'məhsulu': 107126,
#  'olunub': 116852,
#  'qum': 135248,
#  'mam': 95992,
#  'məhəmməd': 107237,
#  'baqirə': 20942,
#  'əza': 212888,
#  'saxlayıri': 147470,
#  'ranın': 139541,
#  'şəhərində': 208125,
#  'zilhiccə': 194668,
#  'ayının': 16797,
#  'si': 150530,
#  'həzrət': 72571,
#  'məhəmmdə': 107235,
#  'baqirin': 20936,
#  'müsibətli': 105291,
#  'şəhadətinin': 208006,
#  'ildönümü': 73719,
#  'münasibətilə': 104760,
#  'mərasimləri': 108525,
#  'keçirilir': 83358,
#  'amfm': 9531,
#  'məsumənin': 109213,
#  'mütəhhər': 105533,
#  'hərəminin': 72138,
#  'qızılı': 137366,
#  'günbəzinə': 64364,
#  'zərihinə': 196234,
#  'qara': 128888,
#  'bayraq': 22260,
#  'yerləşdirilib': 190265,
#  'bundan': 29606,
#  'başqa': 23483,
#  'hərəmin': 72133,
#  'sütunlu': 158058,
#  'dəhlizləri': 46618,
#  'həyətlərində': 72539,
#  'bayraqlar': 22269,
#  'baqirdən': 20934,
#  'hədislər': 71107,
#  'yazılan': 188365,
#  'plakatlar': 123330,
#  'ranlı': 139524,
#  'rejissorun': 140743,
#  'filmi': 55625,
#  'film': 55619,
#  'mükafatına': 104548,
#  'layiq': 92230,
#  'görülüb': 61899,
#  'rejissor': 140709,
#  'yaser': 186976,
#  'talebin': 161691,
#  'çəkdiyi': 200493,
#  'övladlar': 202879,
#  'mükafata': 104472,
#  'lərə': 94809,
#  'veri': 178003,
#  'ekran': 49743,
#  'əsəri': 212151,
#  'təşkil': 173493,
#  'royal': 142702,
#  'star': 154617,
#  'festivalında': 55134,
#  'mükafatını': 104551,
#  'qazanıb': 131300,
#  'filmdə': 55621,
#  'rolları': 142360,
#  'hasan': 67221,
#  'rüstemani': 143411,
#  'viktoria': 179180,
#  'levşenikova': 92765,
#  'hüseyn': 70798,
#  'mirzaguli': 100842,
#  'mehrtaş': 98386,
#  'saidi': 145126,
#  'ile': 73749,
#  'pagah': 119744,
#  'kakasoltani': 80693,
#  'ifa': 73328,
#  'övladını': 202933,
#  'xaricə': 182140,
#  'təhsil': 170513,
#  'almaq': 8371,
#  'göndərən': 61532,
#  'ondan': 117063,
#  'ala': 7482,
#  'bilmədikləri': 25477,
#  'axtarışlara': 15900,
#  'başlayan': 23372,
#  'ailənin': 6753,
#  'yaşadıqlarından': 188748,
#  'bəhs': 31719,
#  'keçirilən': 83449,
#  'longleaf': 93885,
#  'ölən': 202299,
#  'əsir': 211814,
#  'rus': 143108,
#  'əsgərlərin': 211771,
#  'sayını': 147813,
#  'açıqladı': 18121,
#  'suriyanın': 156197,
#  'deyr': 40354,
#  'ez': 53632,
#  'zor': 195127,
#  'əyalətində': 212629,
#  'rusiya': 143131,
#  'əsgəri': 211743,
#  'həlak': 71407,
#  'ikisi': 73597,
#  'mediaya': 98209,
#  'terror': 164613,
#  'qruplaşmasının': 134754,
#  'amak': 9338,
#  'informasiya': 75090,
#  'agentliyi': 6542,
#  'rusiyalı': 143141,
#  'şulya': 207309,
#  'qəsəbəsi': 138568,
#  'döyüşlərin': 45034,
#  'gedişatında': 59071,
#  'bəyanatı': 32437,
#  'rusiyanın': 143157,
#  'müdafiə': 103980,
#  'nazirliyi': 111168,
#  'şərh': 208468,
#  'verməyib': 178480,
#  'ömər': 202370,
#  'cinsi': 34453,
#  'qabiliyyətiniz': 127174,
#  'təyin': 173268,
#  'olunacaq': 116628,
#  'standford': 154572,
#  'universitetin': 174772,
#  'professorları': 125583,
#  'insanın': 75453,
#  'meyillərini': 99448,
#  'fotodan': 56798,
#  'alqorifm': 8606,
#  'düzəldib': 45593,
#  'şəxsiyyət': 208722,
#  'sosial': 153430,
#  'psixologiya': 126284,
#  'jurnalı': 80296,
#  'nda': 111364,
#  'journal': 80155,
#  'of': 115471,
#  'personality': 122154,
#  'and': 9970,
#  'social': 152822,
#  'psychology': 126346,
#  'mövzuya': 103688,
#  'dair': 36687,
#  'yayımlanan': 187965,
#  'məqalədə': 108312,
#  'tək': 170564,
#  'meyli': 99477,
#  'təyinetmə': 173300,
#  'həssaslığının': 72213,
#  'kişilərdə': 85065,
#  '81': 4421,
#  'qadınlarda': 127400,
#  '74': 4213,
#  'bildirilib': 25029,
#  'yer': 190015,
#  'alan': 7541,
#  'müqayisəli': 104981,
#  'məlumatlar': 107593,
#  'insanların': 75420,
#  'mövzuda': 103649,
#  'pis': 123025,
#  'nəticələr': 114820,
#  'verdiyini': 177941,
#  'göstərib': 62457,
#  'mövzu': 103648,
#  'bağlı': 22746,
#  'araşdırmada': 11940,
#  '75': 4232,
#  '000': 1,
#  'insana': 75381,
#  'aid': 6663,
#  'istifadə': 76944,
#  'alqorifmdə': 8607,
#  'olunarkən': 116671,
#  'meylin': 99480,
#  'faizini': 54081,
#  'tapmaq': 162775,
#  'imkanının': 74182,
#  '91': 4652,
#  '83': 4458,
#  'qalxdığı': 128187,
#  'ortaya': 117815,
#  'çıxıb': 200285,
#  'homoseksual': 69681,
#  'fərdlərin': 58336,
#  'qabiliyyətinin': 127173,
#  'edilməsinə': 48889,
#  'verilib': 178079,
#  'kişilərin': 85070,
#  'fərqli': 58407,
#  'üz': 204368,
#  'quruluşu': 135906,
#  'ifadəsi': 73352,
#  'olmasına': 116339,
#  'meylinin': 99483,
#  'doğuluşundan': 43466,
#  'formalaşdığı': 56541,
#  'zümrüd': 195488,
#  'yaxt': 187375,
#  'klub': 85390,
#  'nizamnamə': 112622,
#  'kapitalı': 81320,
#  ...}

# %%
mnb.fit(train_tf,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
test_tf = tfidf.transform(x_test)

# %%
predictions_tf=mnb.predict(test_tf)

# %%
print(classification_report(y_test, predictions_tf))
# accuracy lowered
# Out:
#               precision    recall  f1-score   support
#
#        Dünya       0.73      0.77      0.75      2676
#      Maraqlı       0.68      0.76      0.72      3182
#   Mədəniyyət       0.92      0.04      0.08       301
#      Siyasət       0.81      0.77      0.79      1300
#        İdman       0.91      0.87      0.89      1256
# İqtisadiyyat       0.88      0.78      0.83      1285
#
#     accuracy                           0.76     10000
#    macro avg       0.82      0.67      0.68     10000
# weighted avg       0.77      0.76      0.75     10000

# %%
print(confusion_matrix(y_test, predictions_tf))
# Out:
# [[2062  510    0   48   23   33]
#  [ 533 2425    1   69   75   79]
#  [   6  254   12   27    0    2]
#  [ 143  123    0 1007    2   25]
#  [  31  118    0    8 1097    2]
#  [  59  140    0   80    3 1003]]
